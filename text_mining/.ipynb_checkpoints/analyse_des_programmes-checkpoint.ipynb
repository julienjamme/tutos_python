# %%
# Liste des principaux modules à installer :
# faire des nuages de mots
# !pip install wordcloud
# retirer les accents
# !pip install unidecode
# correction orthographique
# !pip install pyenchant

# chargement de nltk
# !pip install stop_words
# !pip install nltk

# traitement d'image
# !pip install Pillow

# !pip install gensim

# libraririe nlp
# !pip install spacy
import spacy
# !python -m spacy download fr_core_news_sm

# visulaisation LDA
# !pip install pyLDAvis
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp39-cp39-manylinux1_x86_64.whl (363 kB)
#      |████████████████████████████████| 363 kB 7.0 MB/s
# Requirement already satisfied: pillow in /opt/conda/lib/python3.9/site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.9/site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.28.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.1
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 6.9 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.4
# Collecting pyenchant
#   Downloading pyenchant-3.2.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.8 MB/s
# Installing collected packages: pyenchant
# Successfully installed pyenchant-3.2.2
# Collecting stop_words
#   Downloading stop-words-2018.7.23.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: stop-words
#   Building wheel for stop-words (setup.py) ... done
#   Created wheel for stop-words: filename=stop_words-2018.7.23-py3-none-any.whl size=32911 sha256=a5243a7e08e7a156efdaa305fa71119e75ba89a29ee709cad4a0f3648a7cd092
#   Stored in directory: /home/jovyan/.cache/pip/wheels/da/d8/66/395317506a23a9d1d7de433ad6a7d9e6e16aab48cf028a0f60
# Successfully built stop-words
# Installing collected packages: stop-words
# Successfully installed stop-words-2018.7.23
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 7.1 MB/s
# Collecting regex>=2021.8.3
#   Downloading regex-2022.3.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (763 kB)
#      |████████████████████████████████| 763 kB 52.4 MB/s
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from nltk) (4.62.3)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.9/site-packages (from nltk) (8.0.3)
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.7 regex-2022.3.15
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.9/site-packages (8.4.0)
# Collecting gensim
#   Downloading gensim-4.1.2-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.0 MB)
#      |████████████████████████████████| 24.0 MB 16.0 MB/s
# Requirement already satisfied: scipy>=0.18.1 in /opt/conda/lib/python3.9/site-packages (from gensim) (1.7.3)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 20.0 MB/s
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from gensim) (1.20.3)
# Installing collected packages: smart-open, gensim
# Successfully installed gensim-4.1.2 smart-open-5.2.1
# Collecting spacy
#   Downloading spacy-3.2.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 6.6 MB/s
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 5.1 MB/s
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (661 kB)
#      |████████████████████████████████| 661 kB 30.1 MB/s
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.9/site-packages (from spacy) (1.20.3)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.6-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
#      |████████████████████████████████| 128 kB 30.6 MB/s
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#      |████████████████████████████████| 452 kB 22.6 MB/s
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 13.6 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.9/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.9/site-packages (from spacy) (2.26.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp39-cp39-manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 4.2 MB/s
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from spacy) (21.3)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.6-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: click<8.1.0 in /opt/conda/lib/python3.9/site-packages (from spacy) (8.0.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from spacy) (3.0.3)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 10.7 MB/s
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from spacy) (60.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /opt/conda/lib/python3.9/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (4.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, pydantic, preshed, blis, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, spacy
# Successfully installed blis-0.7.7 catalogue-2.0.7 cymem-2.0.6 langcodes-3.3.0 murmurhash-1.0.6 pathy-0.6.1 preshed-3.0.6 pydantic-1.8.2 spacy-3.2.4 spacy-legacy-3.0.9 spacy-loggers-1.0.2 srsly-2.4.2 thinc-8.0.15 typer-0.4.1 wasabi-0.9.1
# Collecting fr-core-news-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.2.0/fr_core_news_sm-3.2.0-py3-none-any.whl (17.4 MB)
#      |████████████████████████████████| 17.4 MB 6.7 MB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from fr-core-news-sm==3.2.0) (3.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (2.26.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (0.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (2.4.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (1.0.6)
# Requirement already satisfied: click<8.1.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (8.0.3)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (1.20.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (0.7.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (21.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (0.9.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (1.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (4.62.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (60.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (3.0.9)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (3.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (0.6.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (8.0.15)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (1.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /opt/conda/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (4.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (2.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->fr-core-news-sm==3.2.0) (2.0.1)
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 8.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (3.0.3)
# Requirement already satisfied: numexpr in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (2.8.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (1.7.3)
# Requirement already satisfied: pandas>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (60.1.0)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: funcy in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: numpy>=1.20.0 in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (1.20.3)
# Requirement already satisfied: future in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.9/site-packages (from pyLDAvis) (4.1.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.2.0->pyLDAvis) (2021.3)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.9/site-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->pyLDAvis) (3.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.16.0)
# Building wheels for collected packages: pyLDAvis, sklearn
#   Building wheel for pyLDAvis (pyproject.toml) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136900 sha256=35ccb0ee77b221b9e67961f642e21cb49c0ba9e7a144d47bcfa90739c2c817c6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/57/a4/86/d10c6c2e0bf149fbc0afb0aa5a6528ac35b30a133a0270c477
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=ac0e00f08e37318f71bab91616a87f9b6aa3674ef98ff4086aced441c9575e23
#   Stored in directory: /home/jovyan/.cache/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built pyLDAvis sklearn
# Installing collected packages: sklearn, pyLDAvis
# Successfully installed pyLDAvis-3.3.1 sklearn-0.0

# %% [markdown]
# ## Import data

# %%
import pandas as pd
data = pd.read_csv('programmes_premier_tour.csv',sep=";", encoding = "UTF-8", quotechar= '"')
print(data.columns)
data.head(5)
# Out:
# Index(['Candidat', 'tendance', 'programme'], dtype='object')
#         Candidat    tendance  \
# 0        Arthaud  Ext.Gauche
# 1  Dupont-Aignan      Droite
#
#                                            programme
# 0   "Travailleuses, travailleurs, En avril 2020, ...
# 1                                          liberté

# %% [markdown]
# ## Nettoyage des programmes

# %% [markdown]
# ### Retrait des accents

# %%
from unidecode import unidecode

def remove_accent(s):
    s = unidecode(s)
    return(s)

data['prog_ss_acc'] = data['programme'].apply(lambda x:remove_accent(str(x)))
print(data.prog_ss_acc[0][:200])
print(data.prog_ss_acc[1][:200])
# Out:
#  "Travailleuses, travailleurs, En avril 2020, pendant le premier confinement, Macron expliquait qu'il faudrait se rappeler que le pays avait tenu grace a celles et ceux << que nos economies reconnaiss
# liberte

# %% [markdown]
# ### Retrait des ponctuations et des chiffres

# %%
import re

def remove_punctuation(s):
    s = re.sub(r'[^A-Za-z]',' ',str(s))
    return(s)

data['prog_ss_punc'] = data['prog_ss_acc'].apply(lambda x:remove_punctuation(str(x)))
data.prog_ss_punc[0][:200]
# Out:
# '  Travailleuses  travailleurs  En avril       pendant le premier confinement  Macron expliquait qu il faudrait se rappeler que le pays avait tenu grace a celles et ceux    que nos economies reconnaiss'

# %% [markdown]
# ### Tout en minuscule et réduction des espaces

# %%
def tolower(s):
    s = ' '.join(s.lower().split())
    return(s)
    
data['prog_minus'] = data['prog_ss_punc'].apply(lambda x:tolower(str(x)))
data.prog_minus[0]
# Out:
# 'travailleuses travailleurs en avril pendant le premier confinement macron expliquait qu il faudrait se rappeler que le pays avait tenu grace a celles et ceux que nos economies reconnaissent et remunerent si mal deux ans plus tard le personnel des hopitaux et des ehpad les aides a la personne les ouvriers de l agroalimentaire et de la logistique les travailleurs des transports les agents de nettoyage et ceux du gardiennage l armee des livreurs et des coursiers les travailleurs de l education nationale continuent d etre sous payes et meprises des travailleurs de la sante sont licencies de fait et prives de salaire en particulier en guadeloupe en martinique et en guyane tous ceux dont les conditions d existence se degradent doivent faire entendre leurs interets profits en hausse et pouvoir d achat en baisse ca suffit suppressions d emplois cadences infernales salaires insuffisants plus les grandes entreprises sont rentables plus leurs actionnaires sont rapaces et s attaquent aux travailleurs alors qu une minorite tres riche s offre des voyages dans l espace il y a sans domicile fixe et plusieurs millions de mal loges des etudiants et des retraites ne survivent que grace a l aide alimentaire les profits se sont envoles pour le plus grand bonheur des riches des grands actionnaires c est a dire de ceux qui ne font rien de leurs dix doigts quand ceux qui se tuent a la tache s appauvrissent et sont precarises la flambee des prix des carburants du gaz de l electricite et de nombre de produits de premiere necessite ne gene pas les grandes fortunes mais pour des millions de femmes et d hommes ce sont de nouvelles privations insupportables il ne faut pas l accepter travailler moins pour travailler tous pouvoir gagner sa vie est une necessite le chomage de masse qui ecarte de toute activite des millions de femmes et d hommes est une aberration comme l est l obligation faite aux plus de ans de s user a la tache alors que tant de jeunes sont au chomage zero chomeur c est possible en se repartissant le travail existant entre tous sans perte de salaire nombre de salaries croulent sous les heures supplementaires les samedis et les jours feries travailles que l on demande aux personnels des hopitaux des ehpad de l education des transports publics d etablir une liste d embauches dont ils auraient besoin on arriverait a des centaines de milliers d emplois utiles et indispensables a creer tout de suite l argent existe rien qu avec les milliards d euros de profits engranges par les premieres societes cotees a la bourse de paris il est possible de creer millions d emplois payes euros cotisations comprises augmentation des salaires et des pensions les travailleurs et les retraites ne demandent pas la charite nous voulons pouvoir vivre de nos salaires ou de nos pensions alors il faut des augmentations de euros par mois contre l inflation il faut imposer l indexation des salaires sur les prix euros c est le minimum pour ne pas avoir a compter chaque euro partir un peu en vacances ou ne pas craindre de se retrouver sans voiture et cela vaut pour les salaires pour les pensions et les allocations des chomeurs et des handicapes le grand patronat ne l accordera jamais mais la plupart du temps il faut faire greve meme pour euros d augmentation alors tant qu a nous battre nous devons revendiquer ce qui est ne cessaire pour vivre nous les travailleurs nous faisons tourner toute la societe et nous n avons aucune raison de nous faire petits euros net au minimum controle des travailleurs sur les comptes des grandes entreprises accepter que les capitalistes exercent leur loi fixent leurs prix et leurs marges a l abri du secret industriel et commer cial c est se resigner a etre les eternels sacrifies c est vrai pour les travailleurs pour les petits paysans comme pour de nombreux petits patrons ecrases par les donneurs d ordres si les grands actionnaires s y opposent il faut les exproprier et placer les grandes entreprises sous le controle de la collec tivite si la  ...

# %% [markdown]
# ### Retrait des mots outils (stopwords)

# %%
import nltk
nltk.download('punkt')

from stop_words import get_stop_words
import unicodedata
from nltk.tokenize import word_tokenize

stopwords = get_stop_words('french')   
stopwords = [unicodedata.normalize('NFKD',m).encode('ASCII', 'ignore').decode() for m in stopwords]
print(stopwords)
# Out:
# ['a', 'ai', 'aie', 'aient', 'aies', 'ait', 'alors', 'as', 'au', 'aucun', 'aura', 'aurai', 'auraient', 'aurais', 'aurait', 'auras', 'aurez', 'auriez', 'aurions', 'aurons', 'auront', 'aussi', 'autre', 'aux', 'avaient', 'avais', 'avait', 'avant', 'avec', 'avez', 'aviez', 'avions', 'avoir', 'avons', 'ayant', 'ayez', 'ayons', 'bon', 'car', 'ce', 'ceci', 'cela', 'ces', 'cet', 'cette', 'ceux', 'chaque', 'ci', 'comme', 'comment', 'd', 'dans', 'de', 'dedans', 'dehors', 'depuis', 'des', 'deux', 'devoir', 'devrait', 'devrez', 'devriez', 'devrions', 'devrons', 'devront', 'dois', 'doit', 'donc', 'dos', 'droite', 'du', 'des', 'debut', 'du', 'elle', 'elles', 'en', 'encore', 'es', 'est', 'et', 'eu', 'eue', 'eues', 'eurent', 'eus', 'eusse', 'eussent', 'eusses', 'eussiez', 'eussions', 'eut', 'eux', 'eumes', 'eut', 'eutes', 'faire', 'fais', 'faisez', 'fait', 'faites', 'fois', 'font', 'force', 'furent', 'fus', 'fusse', 'fussent', 'fusses', 'fussiez', 'fussions', 'fut', 'fumes', 'fut', 'futes', 'haut', 'hors', 'ici', 'il', 'ils', 'j', 'je', 'juste', 'l', 'la', 'le', 'les', 'leur', 'leurs', 'lui', 'la', 'm', 'ma', 'maintenant', 'mais', 'me', 'mes', 'moi', 'moins', 'mon', 'mot', 'meme', 'n', 'ne', 'ni', 'nom', 'nomme', 'nommee', 'nommes', 'nos', 'notre', 'nous', 'nouveau', 'nouveaux', 'on', 'ont', 'ou', 'ou', 'par', 'parce', 'parole', 'pas', 'personne', 'personnes', 'peu', 'peut', 'plupart', 'pour', 'pourquoi', 'qu', 'quand', 'que', 'quel', 'quelle', 'quelles', 'quels', 'qui', 'sa', 'sans', 'se', 'sera', 'serai', 'seraient', 'serais', 'serait', 'seras', 'serez', 'seriez', 'serions', 'serons', 'seront', 'ses', 'seulement', 'si', 'sien', 'soi', 'soient', 'sois', 'soit', 'sommes', 'son', 'sont', 'sous', 'soyez', 'soyons', 'suis', 'sujet', 'sur', 't', 'ta', 'tandis', 'te', 'tellement', 'tels', 'tes', 'toi', 'ton', 'tous', 'tout', 'trop', 'tres', 'tu', 'un', 'une', 'valeur', 'voient', 'vois', 'voit', 'vont', 'vos', 'votre', 'vous', 'vu', 'y', 'a', 'ca', 'etaient', 'etais', 'etait', 'etant', 'etat', 'etiez', 'etions', 'ete', 'etes', 'etes', 'etre']
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stopwords = stopwords + ['c','s','toute','celle','ceux','lundi','mardi','mercredi','jeudi','vendredi','samedi','dimanche','etre','pendant','apres','selon','plus','entre','autre','autres']

# %%
def remove_stopwords(s):
    s = [w for w in word_tokenize(s) if w not in stopwords]
    s = ' '.join(s)
    return(s)

data['prog_ss_stopw'] = data['prog_minus'].apply(lambda x:remove_stopwords(x))
data.prog_ss_stopw[0]
# Out:
# 'travailleuses travailleurs avril premier confinement macron expliquait faudrait rappeler pays tenu grace celles economies reconnaissent remunerent mal ans tard personnel hopitaux ehpad aides ouvriers agroalimentaire logistique travailleurs transports agents nettoyage gardiennage armee livreurs coursiers travailleurs education nationale continuent payes meprises travailleurs sante licencies prives salaire particulier guadeloupe martinique guyane dont conditions existence degradent doivent entendre interets profits hausse pouvoir achat baisse suffit suppressions emplois cadences infernales salaires insuffisants grandes entreprises rentables actionnaires rapaces attaquent travailleurs minorite riche offre voyages espace domicile fixe plusieurs millions mal loges etudiants retraites survivent grace aide alimentaire profits envoles grand bonheur riches grands actionnaires dire rien dix doigts tuent tache appauvrissent precarises flambee prix carburants gaz electricite nombre produits premiere necessite gene grandes fortunes millions femmes hommes nouvelles privations insupportables faut accepter travailler travailler pouvoir gagner vie necessite chomage masse ecarte activite millions femmes hommes aberration obligation faite ans user tache tant jeunes chomage zero chomeur possible repartissant travail existant perte salaire nombre salaries croulent heures supplementaires samedis jours feries travailles demande personnels hopitaux ehpad education transports publics etablir liste embauches dont besoin arriverait centaines milliers emplois utiles indispensables creer suite argent existe rien milliards euros profits engranges premieres societes cotees bourse paris possible creer millions emplois payes euros cotisations comprises augmentation salaires pensions travailleurs retraites demandent charite voulons pouvoir vivre salaires pensions faut augmentations euros mois contre inflation faut imposer indexation salaires prix euros minimum compter euro partir vacances craindre retrouver voiture vaut salaires pensions allocations chomeurs handicapes grand patronat accordera jamais temps faut greve euros augmentation tant battre devons revendiquer cessaire vivre travailleurs faisons tourner societe aucune raison petits euros net minimum controle travailleurs comptes grandes entreprises accepter capitalistes exercent loi fixent prix marges abri secret industriel commer cial resigner eternels sacrifies vrai travailleurs petits paysans nombreux petits patrons ecrases donneurs ordres grands actionnaires opposent faut exproprier placer grandes entreprises controle collec tivite loi profit prive echoue permettre vivre dignement temps disparaisse difficile assurement aucune conquete majeure pos sible lutte ensemble faudra monde travail mene greves massives combats collectifs hopitaux ehpad bas loi profit lits supprimes vingt ans depro grammations fermetures services deserts medicaux pandemie montre gestion comptable sante publique particulier hopital criminelle scandale orpea resulte logique faute investissement public capitalistes mettent main maisons retraite maltraitent anciens tirer toujours argent jusqu dernier jour degradation education nationale transports publics soumis diete voire privatisation resultent memes logiques financieres gouvernements veulent offrir milliards grand patronat durer travailleurs francais immigres camp travailleurs immigres hopital chantier batiment nettoyage aucune usine fonctionnerait travailleurs bien utiles capitalistes arnault bollore serviteurs monde politique doivent droit vote zemmour pen voudraient opposer fran cais etrangers prennent particulier musulmans voudraient france forteresse accueillant milliardaires rejette pauvres laissons diviser seuls beneficiaires capitalistes contre saccage planete rechauffement climatique pollutions catastrophes pays pauvres transformes decharges pays riches gaspillage ressources etats refusent imposer mesures contraignantes capitalistes seuls responsables pollution gouvern ...

# %% [markdown]
# ### Racinisation

# %% [markdown]
# La racinisation peut conduire à perdre la distinction entre l'usage du présent et du conditionnel. Or, dans un discours politique 'doit' et 'devrait' n'ont pas la même force.

# %%
from nltk.stem.snowball import PorterStemmer
from nltk.tokenize import word_tokenize

def stem(s):
    stemmer = PorterStemmer()
    s = [stemmer.stem(w) for w in word_tokenize(s)]
    s = ' '.join(s)
    return(s)

data['prog_stem'] = data['prog_ss_stopw'].apply(lambda x:stem(x))
data.prog_stem[0]
# Out:
# 'travailleus travailleur avril premier confin macron expliquait faudrait rappel pay tenu grace cell economi reconnaiss remuner mal an tard personnel hopitaux ehpad aid ouvrier agroalimentair logistiqu travailleur transport agent nettoyag gardiennag arme livreur coursier travailleur educ national continu pay mepris travailleur sant licenc prive salair particuli guadeloup martiniqu guyan dont condit exist degrad doivent entendr interet profit hauss pouvoir achat baiss suffit suppress emploi cadenc infernal salair insuffis grand entrepris rentabl actionnair rapac attaqu travailleur minorit rich offr voyag espac domicil fix plusieur million mal loge etudi retrait surviv grace aid alimentair profit envol grand bonheur rich grand actionnair dire rien dix doigt tuent tach appauvriss precaris flambe prix carbur gaz electricit nombr produit premier necessit gene grand fortun million femm homm nouvel privat insupport faut accept travail travail pouvoir gagner vie necessit chomag mass ecart activit million femm homm aberr oblig fait an user tach tant jeun chomag zero chomeur possibl repartiss travail exist pert salair nombr salari croulent heur supplementair samedi jour feri travail demand personnel hopitaux ehpad educ transport public etablir list embauch dont besoin arriverait centain millier emploi util indispens creer suit argent exist rien milliard euro profit engrang premier societ cote bours pari possibl creer million emploi pay euro cotis compris augment salair pension travailleur retrait demand charit voulon pouvoir vivr salair pension faut augment euro moi contr inflat faut impos index salair prix euro minimum compter euro partir vacanc craindr retrouv voitur vaut salair pension alloc chomeur handicap grand patronat accordera jamai temp faut greve euro augment tant battr devon revendiqu cessair vivr travailleur faison tourner societ aucun raison petit euro net minimum control travailleur compt grand entrepris accept capitalist exerc loi fixent prix marg abri secret industriel commer cial resign eternel sacrifi vrai travailleur petit paysan nombreux petit patron ecras donneur ordr grand actionnair oppos faut expropri placer grand entrepris control collec tivit loi profit prive echou permettr vivr dignement temp disparaiss difficil assur aucun conquet majeur po sibl lutt ensembl faudra mond travail mene greve massiv combat collectif hopitaux ehpad ba loi profit lit supprim vingt an depro grammat fermetur servic desert medicaux pandemi montr gestion comptabl sant publiqu particuli hopit criminel scandal orpea result logiqu faut investiss public capitalist mettent main maison retrait maltrait ancien tirer toujour argent jusqu dernier jour degrad educ national transport public soumi diet voir privatis result meme logiqu financier gouvern veulent offrir milliard grand patronat durer travailleur francai immigr camp travailleur immigr hopit chantier batiment nettoyag aucun usin fonctionnerait travailleur bien util capitalist arnault bollor serviteur mond politiqu doivent droit vote zemmour pen voudraient oppos fran cai etrang prennent particuli musulman voudraient franc forteress accueil milliardair rejett pauvr laisson divis seul beneficiair capitalist contr saccag planet rechauff climatiqu pollut catastroph pay pauvr transform decharg pay rich gaspillag ressourc etat refus impos mesur contraignant capitalist seul respons pollut gouvern taxent pauvr rich achet droit polluer preserv vironn faut oter pouvoir capita list sauver planet faut mettr fin concurr supprim gachi capitalist dire expropri grand group recens besoin planifi economi libert circul instal contr guerr imperialism guerr ukrain venu brutal rap peler rivalit economiqu politiqu peuvent degener moment poutin declench guerr fratricid etat uni alli sein otan portent responsabilit ecrasant cess aug menter pression militair russi ukrain aujourd hui irak afghanistan hier mepri dictateur poutin vie popul prise etau conflit depass refuson union national derrier dirig troup francais ...

# %% [markdown]
# ### Lemmatisation

# %%
# !pip install git+https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git
# Out:
# Collecting git+https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git
#   Cloning https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git to /tmp/pip-req-build-i7s2u0d_
#   Running command git clone --filter=blob:none -q https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git /tmp/pip-req-build-i7s2u0d_
#   Resolved https://github.com/ClaudeCoulombe/FrenchLefffLemmatizer.git to commit bc0ebd0135a6cc78f48ddf184069b4c0b9c017d8
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: FrenchLefffLemmatizer
#   Building wheel for FrenchLefffLemmatizer (setup.py) ... done
#   Created wheel for FrenchLefffLemmatizer: filename=FrenchLefffLemmatizer-0.3-py3-none-any.whl size=3533528 sha256=3578ed4ff237a0e5caac841f632720686369c46b6caf8095bfbc98fdd8233a78
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gyl6c_hx/wheels/98/2a/68/fa037d302c091a60390195bc19da0a9eb835ff105dbee42c7d
# Successfully built FrenchLefffLemmatizer
# Installing collected packages: FrenchLefffLemmatizer
# Successfully installed FrenchLefffLemmatizer-0.3

# %% [markdown]
# ### Nombre de mots restants à chaque étapes

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize

def matrice_doc_vect(var_text):
    vect = CountVectorizer(lowercase=True)
    dtm = vect.fit_transform(data[var_text].apply(lambda s:str(s)))
    return [vect,dtm]

var_progs = ["programme","prog_ss_punc", "prog_ss_stopw", "prog_stem"]
vect_dtms = [matrice_doc_vect(var) for var in var_progs]

# charger un vectorizer
#vect0 = CountVectorizer(lowercase=True)
# creer la matrice documents x termes à l'aide du vectorizer
#dtm0 = vect0.fit_transform(data["programme"].apply(lambda s:str(s)))

# charger un vectorizer
#vect_ss_punc = CountVectorizer(lowercase=True)
# creer la matrice documents x termes à l'aide du vectorizer
#dtm1 = vect_ss_punc.fit_transform(data["prog_ss_punc"].apply(lambda s:str(s)))

# charger un vectorizer
#vect_ss_stopw = CountVectorizer(lowercase=True)
# creer la matrice documents x termes à l'aide du vectorizer
#dtm2 = vect_ss_stopw.fit_transform(data["prog_ss_stopw"].apply(lambda s:str(s)))


# charger un vectorizer
#vect_stem = CountVectorizer(lowercase=True)
# creer la matrice documents x termes à l'aide du vectorizer
#dtm3 = vect_stem.fit_transform(data["prog_stem"].apply(lambda s:str(s)))

for vdt in vect_dtms:
    print(vdt[1].shape)
# Out:
# (2, 630)
# (2, 616)
# (2, 522)
# (2, 478)

# %% [markdown]
# ## Mots les plus fréquents

# %% [markdown]
# ### Mots les plus fréquents des programmes

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
sns.set_context('paper')

def get_counts_vocabulaire(vect_dtm):
    vocabulaire = pd.concat([pd.Series(vect_dtm[1].toarray().sum(axis=0)),pd.Series(vect_dtm[0].get_feature_names_out())],axis=1)
    vocabulaire.columns = ["nombre","keys"]
    vocabulaire = vocabulaire.sort_values(by=["nombre"],ascending = False)
    vocabulaire = vocabulaire.iloc[:20,]
    return vocabulaire

vocabulaires = [get_counts_vocabulaire(voc) for voc in vect_dtms] 
labels = ["Original","+Sans Ponctuation","+Sans StopWords","+Racinisation"]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,12), facecolor = None)
fig.suptitle('Evolution des occurrences')
for axe, voc, lab in zip(axes.flat, vocabulaires, labels):
    sns.barplot(ax = axe, y = 'keys', x = 'nombre', data = voc, palette = 'magma')
    axe.set_title(lab)

# %% [markdown]
# ### Nombre de mots par programme

# %%
fig, axes = plt.subplots(4, 1, figsize=(8, 7), sharex=True)
sns.despine(left=True)
for ax,vec,lab in zip(axes,vect_dtms,labels):
    sns.distplot(list(vec[1].toarray().sum(axis=1)),ax=ax)
    ax.set_title(lab)
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Nuages de mots

# %%
from wordcloud import WordCloud
#import matplotlib.pyplot as plt

# %%
def make_wordcloud(var_text, candidat):
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white',  
                min_font_size = 10).generate(data[var_text][candidat])
    return wordcloud

# %% [markdown]
# ### Evolution d'un nuage de points par étapes de nettoyage

# %%
wordclouds_arthaud = [make_wordcloud(var, 0) for var in var_progs]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,12), facecolor = None)
fig.suptitle('Evolution du nuage de points sur le programme d\'Arthaud')
for ax,wdcd,lab in zip(axes.flat,wordclouds_arthaud,labels):
    ax.imshow(wdcd)
    ax.set_title(lab) 
    ax.axis("off") 
fig.tight_layout(pad = 2) 

plt.show()

# %% [markdown]
# ### Comparaison des 12 nuages de points

# %%
wordclouds_all = [make_wordcloud("prog_stem", i) for i in range(data.shape[0])]

fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(8,8), facecolor = None)
fig.suptitle('Les nuages de points des 12 programmes')
for ax,wdcd,cand in zip(axes.flat,wordclouds_all,data.Candidat):
    ax.imshow(wdcd)
    ax.set_title(cand) 
    ax.axis("off") 
fig.tight_layout(pad = 2) 

plt.show()
